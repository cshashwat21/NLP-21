# %%
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt
import re
import time 
# %matplotlib inline
import nltk
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.model_selection import train_test_split, StratifiedKFold, KFold, GridSearchCV
from sklearn.feature_selection import SelectKBest, chi2
from sklearn.metrics import accuracy_score, make_scorer
from sklearn import svm, datasets
from nltk.stem import WordNetLemmatizer
from nltk import word_tokenize
from nltk.corpus import wordnet
from nltk import pos_tag
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix, f1_score
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/chandanshashwat/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/chandanshashwat/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/chandanshashwat/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/chandanshashwat/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
os.getcwd()
# Out:
# '/Users/chandanshashwat/Desktop/NLP 21'

# %%
df_original = pd.read_csv("tweet_emotions.csv")

# %%
df = df_original.copy()

# %%
df['sentiment'].unique()
# Out:
# array(['empty', 'sadness', 'enthusiasm', 'neutral', 'worry', 'surprise',
#        'love', 'fun', 'hate', 'happiness', 'boredom', 'relief', 'anger'],
#       dtype=object)

# %%
df.count()
# Out:
# tweet_id     40000
# sentiment    40000
# content      40000
# dtype: int64

# %%
df.head(5)
# Out:
#      tweet_id   sentiment                                            content
# 0  1956967341       empty  @tiffanylue i know  i was listenin to bad habi...
# 1  1956967666     sadness  Layin n bed with a headache  ughhhh...waitin o...
# 2  1956967696     sadness                Funeral ceremony...gloomy friday...
# 3  1956967789  enthusiasm               wants to hang out with friends SOON!
# 4  1956968416     neutral  @dannycastillo We want to trade with someone w...

# %%
df = df.loc[:,['sentiment','content']]

# %%
df.head(2)
# Out:
#   sentiment                                            content
# 0     empty  @tiffanylue i know  i was listenin to bad habi...
# 1   sadness  Layin n bed with a headache  ughhhh...waitin o...

# %%
df['sentiment'] = df['sentiment'].str.lower()

# %%
df.isnull().sum()
# Out:
# sentiment    0
# content      0
# dtype: int64

# %%
df.shape
# Out:
# (40000, 2)

# %%
fig, ax = plt.subplots(figsize=(12,6))
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right')
ax = sns.countplot(x='sentiment', data=df)
i=0
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x()+p.get_width()/2, height + 0.1, df['sentiment'].value_counts()[i], ha='center')
    i+=1
# Out:
# /var/folders/hy/skgp6qs54hb_bmj9gj2tg20m0000gn/T/ipykernel_6712/3762433967.py:2: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right')

# %%
#removing class if any has a value 1
df = df.groupby('sentiment').filter(lambda x : len(x)>1)

#removing stopwords
stop = stopwords.words('english')
df['content'] = df['content'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop)]))

#removing urls
df['content'] = df['content'].apply(lambda x: re.split('https:\/\/.*', str(x))[0])

#removing HTML Tags
def remove_tags(string):
    result = re.sub('<.*?>', '', string)
    return result
df['content'] = df['content'].apply(lambda cw : remove_tags(cw))

#removing '\n' in the code
df['content'] = df['content'].replace('\n', ' ', regex=True)

#removing punctuations
punctuation = '''!()-[]{};:'"\,<>/?@#$%^&*~'''
def remove_punctuations(text):
    for punc in punctuation:
        text = text.replace(punc, '')
    return text
df['content'] = df['content'].apply(remove_punctuations)

#removing digits
df['content'] = df['content'].str.replace('\d+', '')
# Out:
# /var/folders/hy/skgp6qs54hb_bmj9gj2tg20m0000gn/T/ipykernel_6712/905151715.py:29: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['content'] = df['content'].str.replace('\d+', '')

# %%
df.head(5)
# Out:
#     sentiment                                            content
# 0       empty  tiffanylue know listenin bad habit earlier sta...
# 1     sadness       Layin n bed headache ughhhh...waitin call...
# 2     sadness                Funeral ceremony...gloomy friday...
# 3  enthusiasm                            wants hang friends SOON
# 4     neutral  dannycastillo We want trade someone Houston ti...

# %%
#lemmitization
# from nltk.stem import WordNetLemmatizer
# from nltk import word_tokenize

WNlemma = nltk.WordNetLemmatizer()


def get_wordnet_pos(treebank_tag):
    if treebank_tag.startswith('V'):
        return wordnet.VERB
    elif treebank_tag.startswith('J'):
        return wordnet.ADJ
    elif treebank_tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN

def pre_process_with_pos_tag(text):
    text = text.lower()
    tokens = nltk.word_tokenize(text)
    tokens = [t for t in tokens if len(t)>2]
    tokens = [WNlemma.lemmatize(t, get_wordnet_pos(pos_tag(word_tokenize(t))[0][1])) for t in tokens]
    text_after_process = " ".join(tokens)
    return text_after_process

# %%
df['content'] = df['content'].apply(pre_process_with_pos_tag)

# %%
df.head(5)
# Out:
#     sentiment                                            content
# 0       empty  tiffanylue know listenin bad habit earlier sta...
# 1     sadness      layin bed headache ughhhh ... waitin call ...
# 2     sadness             funeral ceremony ... gloomy friday ...
# 3  enthusiasm                              want hang friend soon
# 4     neutral  dannycastillo want trade someone houston ticke...

# %%
#Analysing the words in the content column
results = set()
df['content'].str.lower().str.split().apply(results.update)
print(results)
# Out:
# {'skunk', 'vickie', 'vmas', 'crater', 'kevkevv', 'mrsvaught', 'greypoupon', 'streek', 'katisha_honi', 'smap', 'beateveronica', 'realize', 'encourage', 'liverpoolmich', 'rajtilak', 'walnut', 'lmdlaura', 'etonline.com', 'smokin', 'ddlova', 'maxime', 'denial', 'python', 'commonsense', 'spikecar', 'pak', 'chipper', 'boystown', 'dublinsdave', 'decaf', 'whey', 'toniht', 'faq', 'emilee_marie', 'hawain', 'atcha', 'danholmesimind', 'hedro', 'poof', 'burbankhays', 'httpplurk.comprqc', 'you.quot', 'rolliepollie', 'barrescranton', 'faaaaar', 'darwin', 'stopquot', 'pokeyoats', 'costavidafred', 'judgemental', 'knnnowwww', 'mim', 'tellybelly', 'lisahopecyrus', 'ecas', 'jetgirlart', 'sfs', 'maam', 'nianoelle', 'paulwingz', 'supermodel', 'geehall', 'luk', 'teniece', 'fit', 'fragrance', 'portman', 'nbkorey', 'pretentiousgit', 'myucan', 'compability', 'yeahhhhhyaaaaaa', 'matilda', 'superfro', 'representative', 'therealpickler', 'zemote.com', 'yeahwe', 'grrl', 'moi', 'nctrnlbst', 'marieblue', 'prop', 'no.yes', 'xcourtneylisax', 'shore', 'yang', 'httptinyurl.comckdwao', 'squink', 'patgiblin', 'lamee', 'roseanne', 'kalahari.net', 'randazzled', 'abeen', 'trouble', 'evacuate', 'beccahicklen', 'sharkshocky', 'lizlove', 'rouge', 'mini_ritz', 'denharsh', 'urself', 'tight', 'improvisation', 'cheek', 'gqmf', 'mattthewhoare', 'duuudei', 'janitor', 'discotech', 'frecklesx', 'aampe', 'jana', 'boringquot', 'germany', 'database', 'kellie', 'char', 'viewable', 'welt', 'quadriceps', 'vermouth', 'cache', 'shivshankar', 'challange', 'cspan', 'hiimlianaa', 'httpwww.myspace.combigcitymonkey', 'oberhausen', 'tantrum', 'net', 'pronoun', 'www.audiomicro.com', 'slammin', 'auroraawakes', 'due', 'quotunusual', 'pop', 'easily', 'suncream', 'loonix', 'james_herdman', 'dreeaamy', 'knightinqs', 'darrenporter', 'shorter', 'englisch', 'waaaaaay', 'twitpic', 'kfrieze', 'gentoo', 'goodmorningnight', 'foprof', 'bk_ii', 'soompi', 'japan_blogs', 'shootthestars', 'bowsquot', 'besos', 'peebilicious', 'tassi', 'httptinyurl.comqnjqx', 'guideless', 'httptwitpic.comwmaw', 'lootwise', 'squeal', 'natsmith', 'donbt', 'emmielovegood', 'battlestar', 'tengo', 'httptr.immlz', 'asu', 'voegele', 'runquot', 'kreeoni', 'elegysanft', 'sever', 'lee_bandoni', 'thats', 'four', 'blue_cupcakes', 'sundayshoutout', 'annalisaceccato', 'moreover', 'niene', 'lethargic', 'beadinpath', 'coolin', 'chaperone', 'namastexd', 'pochaccoyoly', 'roughnight', 'communication', 'chantedannyxxx', 'ltlinman', 'hcolephotos', 'nb.in', 'theological', 'mosaicbooks', 'awesome', 'loveeeee', 'urbancritter', 'compose', 'ups', 'microsofts', 'footer', 'gregfairbanks', 'inglewood', 'lovequot', 'crave', 'biatches', 'youd', 'inflict', 'lavsmohan', 'ivanae', 'successorstate', 'vendor', 'love_chrissy', 'ceciliabedelia', 'justkappa', 'rhcp', 'daxx', 'graveyard', 'jwillock', 'roast', 'lolzz', 'andreashale', 'dtatusko', 'couisn', 'maitreya', 'internal', 'marcdavies', 'kawawa', 'hmmpph', 'rubiks', 'half', 'euh', 'www.soompiradio.com', 'cadwaladr', 'dus', 'captive', 'dept', 'amberchase', 'ouchie', 'traceym', 'condom', 'ponet', 'heartbeat', 'hypnosis', 'dichenlachman', 'mahmood', 'festive', 'royle', 'kierantong', 'sarcasticleaves', 'supertriviaguy', 'whasup', 'officialjosephj', 'fairyness', 'diggg', 'casmonaco', 'etc', 'strawfoot', 'httpbit.lyauuac', 'affiliation', 'then.thanks', 'ash_', 'rikkalaniz', 'craftjoshua', 'barrie', 'dawno', 'ysc', 'wieters', 'amisha', 'tactik', 'weekendparis', 'marcos', 'kuso', 'willtothe', 'gprs', 'proposalsquot', 'thekja', 'xanderprod', 'dillematic', 'kapoor', 'spikethelobster', 'tallcree', 'delta', 'grantarnow', 'reason', 'mannyishere', 'dino', 'fungus', 'pub', 'autisticsquot', 'rayamartin', 'againquot', 'kaaeyl', 'zykloid', 'bunnyrenee', 'lanceseabourn', 'keithflaherty', 'trackflashback', 'nova', 'wspnews', 'kerbear', 'batshit', 'oneee', 'trackball', 'ryankanno', 'therealyungberg', 'quotghosts', 'jadeofjades', 'jmike', 'lestockdrop', 'kennedy', 'octopus', 'justinlevy', 'mabaho', 'dolla', 'ssssssssssmack', 'useless ...

# %%
#wordcloud
class_label_0 = df[df['sentiment'] =='happiness']
string_0 = []
for t in class_label_0.content:
    string_0.append(t)
string_0 = pd.Series(string_0).str.cat(sep=' ')
from wordcloud import WordCloud
wordcloud = WordCloud(width=1600, height=800, max_font_size=200).generate(string_0)
plt.figure(figsize=(20,20))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
labelencoder = LabelEncoder()
df['sentiment'] = labelencoder.fit_transform(df['sentiment'])

# %%
x_all = df['content']
y_all = df['sentiment']

# %%
x, x_test, y, y_test = train_test_split(x_all, y_all, stratify=y_all, test_size=0.25, random_state=42)

# %%
vec = CountVectorizer()
x = vec.fit_transform(x)
x_test = vec.transform(x_test)

# %%
clf = svm.SVC(kernel='rbf', gamma=0.5, C=0.1)

# %%
start_time= time.time()
model = clf.fit(x,y)
print("___ %s seconds ---" % (time.time() - start_time))
# Out:
# ___ 146.44929099082947 seconds ---

# %%
predictions = clf.predict(x_test)

# %%
#model.score(x_test, y_test)

# %%
predictions
# Out:
# array([12,  8, 12, ..., 12,  8,  8])

# %%
y_classes = predictions

# %%
y_classes
# Out:
# array([12,  8, 12, ..., 12,  8,  8])

# %%
cf_matrix = confusion_matrix(y_test, y_classes)
cf_matrix
# Out:
# array([[   0,    0,    0,    0,    0,    0,    0,    0,    6,    0,    0,
#            0,   21],
#        [   0,    0,    0,    0,    0,    0,    0,    0,   10,    0,    0,
#            0,   35],
#        [   0,    0,    0,    0,    0,    0,    0,    0,   62,    0,    1,
#            0,  144],
#        [   0,    0,    0,    0,    0,    0,    0,    0,   31,    0,    0,
#            0,  159],
#        [   0,    0,    0,    0,    0,    0,    0,    1,   70,    0,    0,
#            0,  373],
#        [   0,    0,    0,    0,    0,    3,    0,   10,  227,    0,    0,
#            0, 1062],
#        [   0,    0,    0,    0,    0,    0,    0,    0,   45,    0,    1,
#            0,  285],
#        [   0,    0,    0,    0,    0,    2,    0,   75,  128,    0,    1,
#            0,  754],
#        [   0,    0,    0,    0,    0,    1,    0,    7,  696,    0,    2,
#            0, 1453],
#        [   0,    0,    0,    0,    0,    0,    0,    1,   67,    0,    0,
#            0,  314],
#        [   0,    0,    0,    0,    0,    1,    0,    1,  212,    0,    5,
#            0, 1072],
#        [   0,    0,    0,    0,    0,    1,    0,    3,   93,    0,    0,
#            0,  450],
#        [   0,    0,    0,    0,    0,    1,    0,    5,  315,    0,    1,
#            0, 1793]])

# %%
y_prdicted_lables = labelencoder.inverse_transform(y_classes)

# %%
y_prdicted_lables
# Out:
# array(['worry', 'neutral', 'worry', ..., 'worry', 'neutral', 'neutral'],
#       dtype=object)
