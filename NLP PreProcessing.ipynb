# %%
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt
import re
import time 
# %matplotlib inline
import nltk
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.model_selection import train_test_split, StratifiedKFold, KFold, GridSearchCV
from sklearn.feature_selection import SelectKBest, chi2
from sklearn.metrics import accuracy_score, make_scorer
from sklearn.naive_bayes import MultinomialNB
from xgboost import XGBClassifier
from nltk.stem import WordNetLemmatizer
from nltk import word_tokenize
from nltk.corpus import wordnet
from nltk import pos_tag
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/chandanshashwat/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/chandanshashwat/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/chandanshashwat/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/chandanshashwat/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
os.getcwd()
# Out:
# '/Users/chandanshashwat/Desktop/NLP 21'

# %%
df_original = pd.read_csv("tweet_emotions.csv")

# %%
df = df_original.copy()

# %%
df['sentiment'].unique()
# Out:
# array(['empty', 'sadness', 'enthusiasm', 'neutral', 'worry', 'surprise',
#        'love', 'fun', 'hate', 'happiness', 'boredom', 'relief', 'anger'],
#       dtype=object)

# %%
df.count()
# Out:
# tweet_id     40000
# sentiment    40000
# content      40000
# dtype: int64

# %%
df.head(5)
# Out:
#      tweet_id   sentiment                                            content
# 0  1956967341       empty  @tiffanylue i know  i was listenin to bad habi...
# 1  1956967666     sadness  Layin n bed with a headache  ughhhh...waitin o...
# 2  1956967696     sadness                Funeral ceremony...gloomy friday...
# 3  1956967789  enthusiasm               wants to hang out with friends SOON!
# 4  1956968416     neutral  @dannycastillo We want to trade with someone w...

# %%
df = df.loc[:,['sentiment','content']]

# %%
df.head(2)
# Out:
#   sentiment                                            content
# 0     empty  @tiffanylue i know  i was listenin to bad habi...
# 1   sadness  Layin n bed with a headache  ughhhh...waitin o...

# %%
df['sentiment'] = df['sentiment'].str.lower()

# %%
df.isnull().sum()
# Out:
# sentiment    0
# content      0
# dtype: int64

# %%
df.shape
# Out:
# (40000, 2)

# %%
fig, ax = plt.subplots(figsize=(12,6))
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right')
ax = sns.countplot(x='sentiment', data=df)
i=0
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x()+p.get_width()/2, height + 0.1, df['sentiment'].value_counts()[i], ha='center')
    i+=1
# Out:
# /var/folders/hy/skgp6qs54hb_bmj9gj2tg20m0000gn/T/ipykernel_6513/3762433967.py:2: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right')

# %%
#removing class if any has a value 1
df = df.groupby('sentiment').filter(lambda x : len(x)>1)

#removing stopwords
stop = stopwords.words('english')
df['content'] = df['content'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop)]))

#removing urls
df['content'] = df['content'].apply(lambda x: re.split('https:\/\/.*', str(x))[0])

#removing HTML Tags
def remove_tags(string):
    result = re.sub('<.*?>', '', string)
    return result
df['content'] = df['content'].apply(lambda cw : remove_tags(cw))

#removing '\n' in the code
df['content'] = df['content'].replace('\n', ' ', regex=True)

#removing punctuations
punctuation = '''!()-[]{};:'"\,<>/?@#$%^&*~'''
def remove_punctuations(text):
    for punc in punctuation:
        text = text.replace(punc, '')
    return text
df['content'] = df['content'].apply(remove_punctuations)

#removing digits
df['content'] = df['content'].str.replace('\d+', '')
# Out:
# /var/folders/hy/skgp6qs54hb_bmj9gj2tg20m0000gn/T/ipykernel_6513/905151715.py:29: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['content'] = df['content'].str.replace('\d+', '')

# %%
df.head(5)
# Out:
#     sentiment                                            content
# 0       empty  tiffanylue know listenin bad habit earlier sta...
# 1     sadness       Layin n bed headache ughhhh...waitin call...
# 2     sadness                Funeral ceremony...gloomy friday...
# 3  enthusiasm                            wants hang friends SOON
# 4     neutral  dannycastillo We want trade someone Houston ti...

# %%
#lemmitization
# from nltk.stem import WordNetLemmatizer
# from nltk import word_tokenize

WNlemma = nltk.WordNetLemmatizer()


def get_wordnet_pos(treebank_tag):
    if treebank_tag.startswith('V'):
        return wordnet.VERB
    elif treebank_tag.startswith('J'):
        return wordnet.ADJ
    elif treebank_tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN

def pre_process_with_pos_tag(text):
    text = text.lower()
    tokens = nltk.word_tokenize(text)
    tokens = [t for t in tokens if len(t)>2]
    tokens = [WNlemma.lemmatize(t, get_wordnet_pos(pos_tag(word_tokenize(t))[0][1])) for t in tokens]
    text_after_process = " ".join(tokens)
    return text_after_process

# %%
df['content'] = df['content'].apply(pre_process_with_pos_tag)

# %%
df.head(5)
# Out:
#     sentiment                                            content
# 0       empty  tiffanylue know listenin bad habit earlier sta...
# 1     sadness       Layin n bed headache ughhhh...waitin call...
# 2     sadness                Funeral ceremony...gloomy friday...
# 3  enthusiasm                            wants hang friends SOON
# 4     neutral  dannycastillo We want trade someone Houston ti...

# %%
#Analysing the words in the content column
results = set()
df['content'].str.lower().str.split().apply(results.update)
print(results)
# Out:
# {'stoppped', 'cï¿½n', 'garrettmaine', 'duncks', 'lab', 'misterfuji', 'twi', 'hogaan', 'lynny', 'spree.i', 'preacher', 'jamlegend', 'university', 'sexxieluv', 'exotic', 'joyride', 'amandas', 'gaballison', 'nichola_abdo', 'quotgotquot', 'dito', 'disinfect', 'trait', 'espresso', 'pumpkinpeazy', 'aware', 'sashaboucher', 'imperial', 'rightreal', 'jymuzik', 't_rex_', 'summat', 'stellarciarra', 'those', 'dollar', 'homelesscrisis', 'gooooood', 'eeeeeee', 'christineduggan', 'monicafrancesca', 'www.shugartbates.com', 'httpblip.fmzda', 'tracysummers', 'your', 'mirnygirly', 'jaye', 'rewind', 'blogtalkradio', 'drinker', 'terminology', 'markinark', 'whatthelillyyo', 'alices', 'heffabella', 'offend', 'todayi', 'pssthoy', 'goodnight', 'ups', 'otu', 'prix', 'timhaines', 'dash_cunning', 'heloloser', 'delicious.miss', 'quotboyquot', 'robot', 'angiemartinez', 'promisse', 'anyhooo', 'stylish', 'httptr.immoxl', 'holby', 'apartquot', 'ohmyaly', 'rmolden', 'chrislas', 'waitin', 'bill_archie', 'chet', 'hahai', 'bellesouth', 'hahahhah', 'roboroxy', 'scottlava', 'altaf', 'bigdaws', 'lilrainbow', 'marieblue', 'greet', 'sandy_b_', 'morningsteppa', 'millionaire', 'fuckkk', 'mlindvall', 'ouchhhhhh', 'ampa', 'thanksgiving', 'scheme', 'dee', 'tjmodeling', 'httpwww.myfasturl.com', 'bestfriends', 'piraja', 'quotground', 'fckas', 'pare', 'cocont', 'spatter', 'tangible', 'pejua', 'attack', 'translation', 'heyystephieee', 'psst', 'mswilliamsmusic', 'apstylebook', 'ooo', 'heyya', 'indiscrimate', 'skagod', 'kitsilano', 'pilarlovesyou', 'na', 'dennys', 'ï¿½a', 'itin', 'luckily', 'enrollment', 'flashyfem', 'seriooo', 'biafra', 'criticalâ', 'elsietay', 'whcd', 'richhhh', 'danabaker', 'discrepencies', 'exist', 'award', 'chacesmithphoto', 'hrhbrianthecat', 'quotfinal', 'eeeeeeekkkkkkk', 'gloveselectric', 'junoluvsu', 'fledge', 'corber', 'rymartinez', 'creche', 'televise', 'dhair', 'jayc', 'tprettyman', 'celina', 'centos', 'erinmusicluver', 'goodmorningamp', 'slooowww', 'risquethaianna', 'terrellbrw', 'harrisongilmore', 'whoariley', 'scottishtryingtobeirish', 'nige', 'pricing', 'dawson', 'pasty', 'trackball', 'fruityalexia', 'jlandells', 'warrier', 'silly', 'grabrielrossi', 'mansur_rahal', 'bah', 'eftelingfun', 'excite', 'pouch', 'coop', 'horizon', 'imissbradandjen', 'mike_online', 'carlospoulet', 'httptwitpic.comtqx', 'monnie', 'reptar', 'hearing', 'tmzaol', 'forgottten', 'jeffco', 'oatmeal', 'httpaxetech.netforums', 'grangemouth', 'surge', 'germaphobeness', 'httpbudurl.comfp', 'httptinyurl.comotdnu', 'blaaaqhhh', 'release', 'pracc', 'httptr.imkpdw', 'contd', 'fanatic', 'babyfather', 'cause', 'samaasla', 'distract', 'cornbread', 'fuck', 'beaky', 'beernot', 'ackkkk', 'caitiehendry', 'amb', 'guild', 'mizfitonline', 'jon_read', 'ayou', 'socal', 'tci', 'totallywiredm', 'irony', 'thomassmith', 'brand', 'oooowwwch', 'coulda', 'eta', 'kelliehow', 'photojack', 'quotspock.quot', 'transcription', 'nhbs', 'twinz', 'httptwitpic.comwua', 'barg', 'day.quot', 'lollydaskal', 'definitely', 'sigjeans', 'httptwitpic.comhz', 'kerri', 'soo', 'mus', 'benno', 'afectat', 'meebo.com', 'audition', 'ciityliightsx', 'sevenspoons', 'beav', 'yanno', 'brunyc', 'heatherannp', 'laaandan', 'edge', 'amything', 'bwarg', 'chauncey', 'tylerhwilliams', 'boyceavenue', 'andy_hawk', 'rakeem', 'hashim', 'claude', 'mycynts', 'fshionwk', 'maxxie', 'survivor', 'moocow', 'omsvu', 'thaboyophicial', 'human', 'sosimplyme', 'thaank', 'ifebaby', 'phenomenonquot', 'gamegotta', 'buongiorno', 'hyperbirdies', 'krypton', 'demilynnmusic', 'yarinhochman', 'diamondhead', 'marccall', 'lein_', 'whyyy', 'quotfuelquot', 'pisang', 'httptwitpic.comh', 'quotmaggie', 'cps', 'kris_brown', 'juwalbose', 'richardepryor', 'rollerblade', 'social', 'farking', 'talindab', 'lovah', 'ofquotthe', 'effed', 'ohmonika', 'caput', 'dolled', 'ah_lex_ah', 'choco', 'newslite', 'warfield', 'jamesmackney', 'prefer', 'fleece', 'cancertown', 'usuing', 'malennaa', 'tonystark', 'jog', 'logieo', 'rohant', 'keino', 'sproutbox', 'lauurajm', 'sergeant', 'emilyhall', ...

# %%
#wordcloud
class_label_0 = df[df['sentiment'] =='happiness']
string_0 = []
for t in class_label_0.content:
    string_0.append(t)
string_0 = pd.Series(string_0).str.cat(sep=' ')
from wordcloud import WordCloud
wordcloud = WordCloud(width=1600, height=800, max_font_size=200).generate(string_0)
plt.figure(figsize=(20,20))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
